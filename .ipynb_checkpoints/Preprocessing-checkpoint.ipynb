# %% [markdown]
# # Preprocessing

# %%
import pygments.lexers
import numpy as np
import pandas as pd
from gensim.models import Word2Vec

import warnings
warnings.simplefilter('ignore')

import sys
sys.path.append('./reentrancyContracts')
sys.path.append('./reentrancyContractLabels')
import reentrancyContracts
import reentrancyContractLabels

# %% [markdown]
# ### Extract Global Variables

# %%
# takes in full contract and pull out names of global variables (with reasonable accuracy)
def getGlobalVariables(contract):
    lexer = pygments.lexers.get_lexer_by_name('Solidity')
    tokens = list(pygments.lex(contract, lexer))
    globalVarList = []
    openBracketsCount = 0
    openParenthesisCount = 0
    i = 0
    while i < len(tokens):
        if str(tokens[i][0]) == 'Token.Text.Whitespace' or str(tokens[i][0]) == 'Token.Comment.Single': None
        elif(tokens[i][1] == '{'): openBracketsCount += 1
        elif(tokens[i][1] == '}'): openBracketsCount -= 1
        elif(tokens[i][1] == '('): openParenthesisCount += 1
        elif(tokens[i][1] == ')'): openParenthesisCount -= 1
        elif(str(tokens[i][0]) == 'Token.Keyword.Type' and isType(tokens[i][1]) and openBracketsCount == 1 and openParenthesisCount == 0):
            index = 0
            potentialGlobal = ""
            include = True
            while True:
                if(tokens[i+index][1] == "constant"): 
                    include = False
                if(tokens[i+index][1] == ';'):
                    if include:
                        globalVarList.append(potentialGlobal)
                    break
                if(tokens[i+index][0] == pygments.token.Name.Variable or tokens[i+index][0] == pygments.token.Text):
                    potentialGlobal = tokens[i+index][1]
                    
                index += 1
            i += (index-1)
        i += 1
        
    return globalVarList

# %% [markdown]
# ### Extract Modifiers

# %%
def getModifiers(contract):
    lexer = pygments.lexers.get_lexer_by_name('Solidity')
    tokens = list(pygments.lex(contract, lexer))
    filteredTokens = []
    for token in tokens:
        if str(token[0]) != 'Token.Text.Whitespace':
            filteredTokens.append(token)
            
    modifierNameList = []
    openBracketsCount = 0
    openParenthesisCount = 0
    i = 0
    while i < len(filteredTokens):
        if(str(filteredTokens[i][0]) == 'Token.Keyword.Type' and str(filteredTokens[i][1]) == 'modifier'):
            modifierNameList.append(filteredTokens[i+1][1])
        
        i += 1
        
    return modifierNameList

# %%
getModifiers(reentrancyContracts.contracts[22])
# Out:
# ['onlyOwner', 'isOpenToPublic', 'onlyRealPeople', 'onlyPlayers']

# %% [markdown]
# ### Tokenize Functions

# %%
# tokenize a given function
def tokenize(parsedFunction, globalVariablesList, modifierNameList):
    txKeywords = ['call', 'value', 'transfer', 'send']
    tokenList = []
    for tup in parsedFunction:
        if tokenList and tokenList[-1] == "function":
            tokenList.append("Token.FunctionName")
        elif str(tup[1]) in txKeywords:
            tokenList.append(tup[1])
        elif 'Token.Literal' in str(tup[0]):
            tokenList.append("Token.Constant")
        elif tup[1] in globalVariablesList:
            tokenList.append("Token.GlobalVariable")
        elif tup[1] in modifierNameList:
            tokenList.append("Token.ModifierName")
        elif tup[1].startswith("\""):
            tokenList.append("Token.String")
        elif str(tup[0]) == 'Token.Name.Variable' or str(tup[0]) == 'Token.Text':
            tokenList.append("Token.LocalVariable")
        elif str(tup[0]) != 'Token.Text.Whitespace' and str(tup[0]) != 'Token.Comment.Single':
            tokenList.append(tup[1])
    return tokenList

# %%
# checks if keyword is for variable declaration (helper for global variable parser)
def isType(word):
    keywords = ['address', 'bool', 'byte', 'bytes', 'int', 'string', 'uint', 'mapping']
    for kw in keywords:
        if kw in word:
            return True
    return False

# %%
def getFunctions(contract):
    lexer = pygments.lexers.get_lexer_by_name('Solidity')
    tokens = list(pygments.lex(contract, lexer))
    functionList = []
    i = 0
    while i < len(tokens):
        if str(tokens[i][0]) == "Token.Keyword.Type" and tokens[i][1] == 'function':
            currFunctionNum = len(functionList)
            functionList.append([tokens[i]])
            i += 1
            
            oneLiner = False
            while tokens[i][1] != '{':
                # the one-liner case
                if str(tokens[i][1]) == ';':
                    i += 1
                    oneLiner = True
                    break
                if str(tokens[i][0]) != 'Token.Text.Whitespace' and str(tokens[i][0]) != 'Token.Comment.Single':
                    functionList[currFunctionNum].append(tokens[i])
                i += 1
                
            functionList[currFunctionNum].append(tokens[i])
            openBracketsCount = 1
            i += 1
            
            while openBracketsCount > 0:
                if(tokens[i][1] == '{'): openBracketsCount += 1
                elif(tokens[i][1] == '}'): openBracketsCount -= 1
                
                if str(tokens[i][0]) != 'Token.Text.Whitespace' and str(tokens[i][0]) != 'Token.Comment.Single':
                    functionList[currFunctionNum].append(tokens[i])
                i += 1
        else:
            i += 1
    return functionList

# %%
# processing pipeline:
# - receives contract
# - extracts list of global variable names
# - extracts list of modifier names
# - extracts list of function source code
# - creates tokenized list of functions
# - vectorizes tokenized function list by word2vec vectors

def tokenizeContractFunctions(contract):
    globalVariablesList = getGlobalVariables(contract)
    modifierNameList = getModifiers(contract)
    functionList = getFunctions(contract)
    
    tokenizedFunctionList = []
    for function in functionList:
        tokenizedFunction = tokenize(function, globalVariablesList, modifierNameList)
        tokenizedFunctionList.append(tokenizedFunction)
    
    return tokenizedFunctionList

# %% [markdown]
# ### Create DataFrame

# %%
def createTuples(tokenizedFunctions, labels):
    tuples = []
    for i in range(len(tokenizedFunctions)):
        
        tuples.append([tokenizedFunctions[i], labels[i]])
    return tuples

# %%
def createDataFrame(contracts, contractLabels):
    df = pd.DataFrame(columns=['tokenized_function', 'label'])
    for i in range(len(contracts)):
        tokenizedFunctions = tokenizeContractFunctions(contracts[i])
        tuples = createTuples(tokenizedFunctions, contractLabels[i])
        appendable = pd.DataFrame(tuples, columns=['tokenized_function', 'label'])
        df = df.append(appendable, ignore_index=True)
    
    return df

# %%
# df = createDataFrame(reentrancyContracts.contracts, reentrancyContractLabels.labels)

# %%
def returnData(contracts, contractLabels):
    functions = []
    labels = []
    for i in range(len(contracts)):
        tokenizedFunctions = tokenizeContractFunctions(contracts[i])
        functions.extend(tokenizedFunctions)
        labels.extend(contractLabels[i])
    
    return [functions, labels]

# %% [markdown]
# ### Create Embeddings

# %%
def get_w2v_mapping(tokenizedFunctionsDf, token_dim):
    w2v = Word2Vec(tokenizedFunctionsDf, min_count=1, size=token_dim, workers=3, window=3, sg=1)
    return w2v

# %%
def vectorize_functions(tokenizedFunctionsDf, w2v_mapping):
    embedding_list = []
    for i in range(len(tokenizedFunctionsDf)):
        embedding = []
        for token in tokenizedFunctionsDf[i]:
            embedding.append(w2v_mapping[token])
        
        embedding_list.append(embedding)
    return embedding_list

# %%
def pad_embeddings(embeddings, max_length, token_dim):
    padded_embeddings = []
    for embedding in embeddings:
        zero_padding_cnt = max_length - len(embedding)
        pad = np.zeros((1, token_dim))
        for i in range(zero_padding_cnt):
            embedding = np.concatenate((embedding, pad), axis=0)
        padded_embeddings.append(embedding)
    return padded_embeddings

# %%
def getFunctionEmbeddings(tokenizedFunctions, max_length, token_dim):
    print("tokenized fns: ", type(functions))
    w2v_mapping = get_w2v_mapping(tokenizedFunctions, token_dim)
    vectorized_fns = vectorize_functions(tokenizedFunctions, w2v_mapping)
    print("vect fns: ", type(vectorized_fns))
    padded_embeddings = pad_embeddings(vectorized_fns, max_length, token_dim)
    print("padded fns: ", type(padded_embeddings))
    return [w2v_mapping, padded_embeddings]

# %%
length = 500
token_dim = 15

[functions, labels] = returnData(reentrancyContracts.contracts, reentrancyContractLabels.labels)
[w2v_mapping, fn_embeddings] = getFunctionEmbeddings(functions, length, token_dim)
fn_embeddings = np.array(fn_embeddings)
fn_embeddings.shape
# Out:
# tokenized fns:  <class 'list'>
# vect fns:  <class 'list'>
# padded fns:  <class 'list'>
# (432, 500, 15)

# %% [markdown]
# # Model

# %%
import warnings
warnings.simplefilter('ignore')

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import classification_report

import tensorflow as tf
from keras import layers, regularizers, Input
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, LSTM, Flatten, Embedding, Dropout
from keras import metrics

# %%
[functions, labels] = returnData(reentrancyContracts.contracts, reentrancyContractLabels.labels)
[w2v_mapping, X_train] = getFunctionEmbeddings(functions, 500, 15)
X = np.array(X_train)
y = to_categorical(np.array(labels))
X_train = X[30:]
y_train = y[30:]
X_test = X[:30]
y_test = y[:30]
# Out:
# tokenized fns:  <class 'list'>
# vect fns:  <class 'list'>
# padded fns:  <class 'list'>

# %%
X_train.shape
# Out:
# (402, 500, 15)

# %%
y_train.shape
# Out:
# (402, 2)

# %%
vocab_size = len(w2v_mapping.wv.vocab)
embedding_dim = 15
embeddings_per_example = 500

model = Sequential()
model.add(layers.Conv1D(128, 5, activation='relu'))
model.add(layers.GlobalMaxPooling1D())
model.add(layers.Dense(10, activation='relu'))
model.add(Dropout(0.2))
model.add(layers.Dense(2, activation='sigmoid'))

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=30, epochs=200, verbose=1)
# Out:
# Train on 402 samples, validate on 30 samples
# Epoch 1/200
# 402/402 [==============================] - 1s 2ms/step - loss: 0.6892 - accuracy: 0.5137 - val_loss: 0.6479 - val_accuracy: 0.7667
# Epoch 2/200
# 402/402 [==============================] - 0s 498us/step - loss: 0.6573 - accuracy: 0.5709 - val_loss: 0.6310 - val_accuracy: 0.7667
# Epoch 3/200
# 402/402 [==============================] - 0s 487us/step - loss: 0.6401 - accuracy: 0.5995 - val_loss: 0.6348 - val_accuracy: 0.7000
# Epoch 4/200
# 402/402 [==============================] - 0s 458us/step - loss: 0.6340 - accuracy: 0.6318 - val_loss: 0.6257 - val_accuracy: 0.7000
# Epoch 5/200
# 402/402 [==============================] - 0s 447us/step - loss: 0.6166 - accuracy: 0.6704 - val_loss: 0.6091 - val_accuracy: 0.6833
# Epoch 6/200
# 402/402 [==============================] - 0s 435us/step - loss: 0.6028 - accuracy: 0.7301 - val_loss: 0.5980 - val_accuracy: 0.7500
# Epoch 7/200
# 402/402 [==============================] - 0s 451us/step - loss: 0.5958 - accuracy: 0.6903 - val_loss: 0.6216 - val_accuracy: 0.6000
# Epoch 8/200
# 402/402 [==============================] - 0s 555us/step - loss: 0.5858 - accuracy: 0.7413 - val_loss: 0.5920 - val_accuracy: 0.6500
# Epoch 9/200
# 402/402 [==============================] - 0s 566us/step - loss: 0.5769 - accuracy: 0.7674 - val_loss: 0.6039 - val_accuracy: 0.6167
# Epoch 10/200
# 402/402 [==============================] - 0s 485us/step - loss: 0.5765 - accuracy: 0.7525 - val_loss: 0.6138 - val_accuracy: 0.6167
# Epoch 11/200
# 402/402 [==============================] - 0s 460us/step - loss: 0.5588 - accuracy: 0.8047 - val_loss: 0.5889 - val_accuracy: 0.6167
# Epoch 12/200
# 402/402 [==============================] - 0s 478us/step - loss: 0.5572 - accuracy: 0.7674 - val_loss: 0.6217 - val_accuracy: 0.6167
# Epoch 13/200
# 402/402 [==============================] - 0s 505us/step - loss: 0.5461 - accuracy: 0.8097 - val_loss: 0.6051 - val_accuracy: 0.6167
# Epoch 14/200
# 402/402 [==============================] - 0s 504us/step - loss: 0.5385 - accuracy: 0.8234 - val_loss: 0.6002 - val_accuracy: 0.6167
# Epoch 15/200
# 402/402 [==============================] - 0s 436us/step - loss: 0.5348 - accuracy: 0.8022 - val_loss: 0.6114 - val_accuracy: 0.6000
# Epoch 16/200
# 402/402 [==============================] - 0s 454us/step - loss: 0.5350 - accuracy: 0.8209 - val_loss: 0.6118 - val_accuracy: 0.6167
# Epoch 17/200
# 402/402 [==============================] - 0s 442us/step - loss: 0.5313 - accuracy: 0.8159 - val_loss: 0.6119 - val_accuracy: 0.6167
# Epoch 18/200
# 402/402 [==============================] - 0s 459us/step - loss: 0.5219 - accuracy: 0.8221 - val_loss: 0.6118 - val_accuracy: 0.6333
# Epoch 19/200
# 402/402 [==============================] - 0s 459us/step - loss: 0.5250 - accuracy: 0.8147 - val_loss: 0.6087 - val_accuracy: 0.6333
# Epoch 20/200
# 402/402 [==============================] - 0s 490us/step - loss: 0.5164 - accuracy: 0.8209 - val_loss: 0.6249 - val_accuracy: 0.6000
# Epoch 21/200
# 402/402 [==============================] - 0s 467us/step - loss: 0.5136 - accuracy: 0.8246 - val_loss: 0.6203 - val_accuracy: 0.6000
# Epoch 22/200
# 402/402 [==============================] - 0s 484us/step - loss: 0.5062 - accuracy: 0.8383 - val_loss: 0.6235 - val_accuracy: 0.5667
# Epoch 23/200
# 402/402 [==============================] - 0s 467us/step - loss: 0.4998 - accuracy: 0.8271 - val_loss: 0.6366 - val_accuracy: 0.6333
# Epoch 24/200
# 402/402 [==============================] - 0s 489us/step - loss: 0.4993 - accuracy: 0.8271 - val_loss: 0.6226 - val_accuracy: 0.5833
# Epoch 25/200
# 402/402 [==============================] - 0s 481us/step - loss: 0.4923 - accuracy: 0.8259 - val_loss: 0.6287 - val_accuracy: 0.6000
# Epoch 26/200
# 402/402 [==============================] - 0s 469us/step - loss: 0.4919 - accuracy: 0.8308 - val_loss: 0.6282 - val_accuracy: 0.5667
# Epoch 27/200
# 402/402 [==============================] - 0s 501us/step - loss: 0.4846 - accuracy: 0.8346 - val_loss: 0.6277 - val_accuracy: 0.6167
# Epoch 28/200
# 402/402 [==============================] - 0s 419us/step - loss: 0.4786 - accuracy: 0.8333 - val_loss: 0.6296 - val_accuracy: 0.6000
# Epoch 29/200
# 402/402 [==============================] - 0s 416us/step - loss: 0.4708 - accuracy: 0.8470 - val_loss: 0.6321 - val_accuracy: 0.6000
# Epoch 30/200
# 402/402 [==============================] - 0s 418us/step - loss: 0.4784 - accuracy: 0.8433 - val_loss: 0.6302 - val_accuracy: 0.6333
# Epoch 31/200
# 402/402 [==============================] - 0s 463us/step - loss: 0.4768 - accuracy: 0.8458 - val_loss: 0.6268 - val_accuracy: 0.6167
# Epoch 32/200
# 402/402 [==============================] - 0s 468us/step - loss: 0.4708 - accuracy: 0.8470 - val_loss: 0.6392 - val_accuracy: 0.6333
# Epoch 33/200
# 402/402 [==============================] - 0s 494us/step - loss: 0.4624 - accuracy: 0.8507 - val_loss: 0.6433 - val_accuracy: 0.6333
# Epoch 34/200
# 402/402 [==============================] - 0s 472us/step - loss: 0.4638 - accuracy: 0.8507 - val_loss: 0.6340 - val_accuracy: 0.6000
# Epoch 35/200
# 402/402 [==============================] - 0s 475us/step - loss: 0.4514 - accuracy: 0.8532 - val_loss: 0.6334 - val_accuracy: 0.6333
# Epoch 36/200
# 402/402 [==============================] - 0s 509us/step - loss: 0.4552 - accuracy: 0.8545 - val_loss: 0.6461 - val_accuracy: 0.6667
# Epoch 37/200
# 402/402 [==============================] - 0s 478us/step - loss: 0.4498 - accuracy: 0.8607 - val_loss: 0.6441 - val_accuracy: 0.6667
# Epoch 38/200
# 402/402 [==============================] - 0s 487us/step - loss: 0.4496 - accuracy: 0.8607 - val_loss: 0.6435 - val_accuracy: 0.6000
# Epoch 39/200
# 402/402 [==============================] - 0s 503us/step - loss: 0.4426 - accuracy: 0.8694 - val_loss: 0.6423 - val_accuracy: 0.5833
# Epoch 40/200
# 402/402 [==============================] - 0s 471us/step - loss: 0.4407 - accuracy: 0.8582 - val_loss: 0.6647 - val_accuracy: 0.6333
# Epoch 41/200
# 402/402 [==============================] - 0s 473us/step - loss: 0.4355 - accuracy: 0.8557 - val_loss: 0.6550 - val_accuracy: 0.6667
# Epoch 42/200
# 402/402 [==============================] - 0s 473us/step - loss: 0.4352 - accuracy: 0.8632 - val_loss: 0.6483 - val_accuracy: 0.6500
# Epoch 43/200
# 402/402 [==============================] - 0s 472us/step - loss: 0.4237 - accuracy: 0.8706 - val_loss: 0.6516 - val_accuracy: 0.6000
# Epoch 44/200
# 402/402 [==============================] - 0s 478us/step - loss: 0.4211 - accuracy: 0.8644 - val_loss: 0.6468 - val_accuracy: 0.5833
# Epoch 45/200
# 402/402 [==============================] - 0s 481us/step - loss: 0.4184 - accuracy: 0.8769 - val_loss: 0.6512 - val_accuracy: 0.6167
# Epoch 46/200
# 402/402 [==============================] - 0s 433us/step - loss: 0.4247 - accuracy: 0.8595 - val_loss: 0.6510 - val_accuracy: 0.6333
# Epoch 47/200
# 402/402 [==============================] - 0s 417us/step - loss: 0.4258 - accuracy: 0.8607 - val_loss: 0.6618 - val_accuracy: 0.6667
# Epoch 48/200
# 402/402 [==============================] - 0s 383us/step - loss: 0.4139 - accuracy: 0.8694 - val_loss: 0.6570 - val_accuracy: 0.7000
# Epoch 49/200
# 402/402 [==============================] - 0s 417us/step - loss: 0.4129 - accuracy: 0.8644 - val_loss: 0.6540 - val_accuracy: 0.6667
# Epoch 50/200
# 402/402 [==============================] - 0s 442us/step - loss: 0.4077 - accuracy: 0.8781 - val_loss: 0.6682 - val_accuracy: 0.6167
# Epoch 51/200
# 402/402 [==============================] - 0s 489us/step - loss: 0.3926 - accuracy: 0.8794 - val_loss: 0.6605 - val_accuracy: 0.6000
# Epoch 52/200
# 402/402 [==============================] - 0s 503us/step - loss: 0.3938 - accuracy: 0.8731 - val_loss: 0.6572 - val_accuracy: 0.6167
# Epoch 53/200
# 402/402 [==============================] - 0s 472us/step - loss: 0.3874 - accuracy: 0.8769 - val_loss: 0.6626 - val_accuracy: 0.6333
# Epoch 54/200
# 402/402 [==============================] - 0s 470us/step - loss: 0.3870 - accuracy: 0.8781 - val_loss: 0.6529 - val_accuracy: 0.7000
# Epoch 55/200
# 402/402 [==============================] - 0s 428us/step - loss: 0.3785 - accuracy: 0.8806 - val_loss: 0.6529 - val_accuracy: 0.7000
# Epoch 56/200
# 402/402 [==============================] - 0s 448us/step - loss: 0.3799 - accuracy: 0.8818 - val_loss: 0.6516 - val_accuracy: 0.7000
# Epoch 57/200
# 402/402 [==============================] - 0s 457us/step - loss: 0.3714 - accuracy: 0.8905 - val_loss: 0.6542 - val_accuracy: 0.7000
# Epoch 58/200
# 402/402 [==============================] - 0s 477us/step - loss: 0.3812 - accuracy: 0.8843 - val_loss: 0.6567 - val_accuracy: 0.7000
# Epoch 59/200
# 402/402 [==============================] - 0s 451us/step - loss: 0.3913 - accuracy: 0.8818 - val_loss: 0.6686 - val_accuracy: 0.7000
# Epoch 60/200
# 402/402 [==============================] - 0s 454us/step - loss: 0.3781 - accuracy: 0.8868 - val_loss: 0.6775 - val_accuracy: 0.6333
# Epoch 61/200
# 402/402 [==============================] - 0s 465us/step - loss: 0.3850 - accuracy: 0.8682 - val_loss: 0.6645 - val_accuracy: 0.7000
# Epoch 62/200
# 402/402 [==============================] - 0s 485us/step - loss: 0.3718 - accuracy: 0.8918 - val_loss: 0.6747 - val_accuracy: 0.7000
# Epoch 63/200
# 402/402 [==============================] - 0s 480us/step - loss: 0.3625 - accuracy: 0.8980 - val_loss: 0.6649 - val_accuracy: 0.6833
# Epoch 64/200
# 402/402 [==============================] - 0s 468us/step - loss: 0.3572 - accuracy: 0.8831 - val_loss: 0.6870 - val_accuracy: 0.6833
# Epoch 65/200
# 402/402 [==============================] - 0s 453us/step - loss: 0.3533 - accuracy: 0.8893 - val_loss: 0.6854 - val_accuracy: 0.7167
# Epoch 66/200
# 402/402 [==============================] - 0s 473us/step - loss: 0.3343 - accuracy: 0.8993 - val_loss: 0.6931 - val_accuracy: 0.7167
# Epoch 67/200
# 402/402 [==============================] - 0s 428us/step - loss: 0.3248 - accuracy: 0.9042 - val_loss: 0.6848 - val_accuracy: 0.7167
# Epoch 68/200
# 402/402 [==============================] - 0s 438us/step - loss: 0.3273 - accuracy: 0.9017 - val_loss: 0.7095 - val_accuracy: 0.6833
# Epoch 69/200
# 402/402 [==============================] - 0s 407us/step - loss: 0.3136 - accuracy: 0.9092 - val_loss: 0.7056 - val_accuracy: 0.7167
# Epoch 70/200
# 402/402 [==============================] - 0s 456us/step - loss: 0.3140 - accuracy: 0.9030 - val_loss: 0.7143 - val_accuracy: 0.7167
# Epoch 71/200
# 402/402 [==============================] - 0s 458us/step - loss: 0.3281 - accuracy: 0.8893 - val_loss: 0.7233 - val_accuracy: 0.6833
# Epoch 72/200
# 402/402 [==============================] - 0s 491us/step - loss: 0.3124 - accuracy: 0.9017 - val_loss: 0.7118 - val_accuracy: 0.7000
# Epoch 73/200
# 402/402 [==============================] - 0s 475us/step - loss: 0.3028 - accuracy: 0.9117 - val_loss: 0.7203 - val_accuracy: 0.7167
# Epoch 74/200
# 402/402 [==============================] - 0s 454us/step - loss: 0.3088 - accuracy: 0.9030 - val_loss: 0.7115 - val_accuracy: 0.7500
# Epoch 75/200
# 402/402 [==============================] - 0s 429us/step - loss: 0.2978 - accuracy: 0.9067 - val_loss: 0.7183 - val_accuracy: 0.7333
# Epoch 76/200
# 402/402 [==============================] - 0s 374us/step - loss: 0.2844 - accuracy: 0.9117 - val_loss: 0.7488 - val_accuracy: 0.7333
# Epoch 77/200
# 402/402 [==============================] - 0s 364us/step - loss: 0.2781 - accuracy: 0.9129 - val_loss: 0.7399 - val_accuracy: 0.7167
# Epoch 78/200
# 402/402 [==============================] - 0s 379us/step - loss: 0.2874 - accuracy: 0.9129 - val_loss: 0.7394 - val_accuracy: 0.7167
# Epoch 79/200
# 402/402 [==============================] - 0s 354us/step - loss: 0.2744 - accuracy: 0.9229 - val_loss: 0.7349 - val_accuracy: 0.7500
# Epoch 80/200
# 402/402 [==============================] - 0s 406us/step - loss: 0.2742 - accuracy: 0.9154 - val_loss: 0.7261 - val_accuracy: 0.7500
# Epoch 81/200
# 402/402 [==============================] - 0s 372us/step - loss: 0.2691 - accuracy: 0.9142 - val_loss: 0.7351 - val_accuracy: 0.7333
# Epoch 82/200
# 402/402 [==============================] - 0s 392us/step - loss: 0.2815 - accuracy: 0.9080 - val_loss: 0.7572 - val_accuracy: 0.7500
# Epoch 83/200
# 402/402 [==============================] - 0s 371us/step - loss: 0.2771 - accuracy: 0.9117 - val_loss: 0.7439 - val_accuracy: 0.7500
# Epoch 84/200
# 402/402 [==============================] - 0s 384us/step - loss: 0.2509 - accuracy: 0.9192 - val_loss: 0.7366 - val_accuracy: 0.7500
# Epoch 85/200
# 402/402 [==============================] - 0s 380us/step - loss: 0.2616 - accuracy: 0.9142 - val_loss: 0.7550 - val_accuracy: 0.7333
# Epoch 86/200
# 402/402 [==============================] - 0s 389us/step - loss: 0.2573 - accuracy: 0.9154 - val_loss: 0.7364 - val_accuracy: 0.7333
# Epoch 87/200
# 402/402 [==============================] - 0s 368us/step - loss: 0.2529 - accuracy: 0.9142 - val_loss: 0.7425 - val_accuracy: 0.7333
# Epoch 88/200
# 402/402 [==============================] - 0s 379us/step - loss: 0.2440 - accuracy: 0.9167 - val_loss: 0.7515 - val_accuracy: 0.7333
# Epoch 89/200
# 402/402 [==============================] - 0s 398us/step - loss: 0.2543 - accuracy: 0.9266 - val_loss: 0.7368 - val_accuracy: 0.7500
# Epoch 90/200
# 402/402 [==============================] - 0s 398us/step - loss: 0.2617 - accuracy: 0.9129 - val_loss: 0.7969 - val_accuracy: 0.7167
# Epoch 91/200
# 402/402 [==============================] - 0s 394us/step - loss: 0.2570 - accuracy: 0.9167 - val_loss: 0.8290 - val_accuracy: 0.7167
# Epoch 92/200
# 402/402 [==============================] - 0s 486us/step - loss: 0.2823 - accuracy: 0.9080 - val_loss: 0.7426 - val_accuracy: 0.7500
# Epoch 93/200
# 402/402 [==============================] - 0s 495us/step - loss: 0.2799 - accuracy: 0.9104 - val_loss: 0.7594 - val_accuracy: 0.7667
# Epoch 94/200
# 402/402 [==============================] - 0s 451us/step - loss: 0.2449 - accuracy: 0.9291 - val_loss: 0.7521 - val_accuracy: 0.7500
# Epoch 95/200
# 402/402 [==============================] - 0s 485us/step - loss: 0.2360 - accuracy: 0.9241 - val_loss: 0.7564 - val_accuracy: 0.7333
# Epoch 96/200
# 402/402 [==============================] - 0s 533us/step - loss: 0.2578 - accuracy: 0.9192 - val_loss: 0.7881 - val_accuracy: 0.7333
# Epoch 97/200
# 402/402 [==============================] - 0s 483us/step - loss: 0.2437 - accuracy: 0.9291 - val_loss: 0.7904 - val_accuracy: 0.7333
# Epoch 98/200
# 402/402 [==============================] - 0s 534us/step - loss: 0.2460 - accuracy: 0.9254 - val_loss: 0.7771 - val_accuracy: 0.7167
# Epoch 99/200
# 402/402 [==============================] - 0s 465us/step - loss: 0.2418 - accuracy: 0.9341 - val_loss: 0.7474 - val_accuracy: 0.7333
# Epoch 100/200
# 402/402 [==============================] - 0s 429us/step - loss: 0.2347 - accuracy: 0.9216 - val_loss: 0.7450 - val_accuracy: 0.7333
# Epoch 101/200
# 402/402 [==============================] - 0s 397us/step - loss: 0.2399 - accuracy: 0.9316 - val_loss: 0.7681 - val_accuracy: 0.8000
# Epoch 102/200
# 402/402 [==============================] - 0s 393us/step - loss: 0.2421 - accuracy: 0.9316 - val_loss: 0.7776 - val_accuracy: 0.8000
# Epoch 103/200
# 402/402 [==============================] - 0s 447us/step - loss: 0.2339 - accuracy: 0.9303 - val_loss: 0.7791 - val_accuracy: 0.7667
# Epoch 104/200
# 402/402 [==============================] - 0s 412us/step - loss: 0.2337 - accuracy: 0.9316 - val_loss: 0.7916 - val_accuracy: 0.8000
# Epoch 105/200
# 402/402 [==============================] - 0s 412us/step - loss: 0.2329 - accuracy: 0.9279 - val_loss: 0.8176 - val_accuracy: 0.8000
# Epoch 106/200
# 402/402 [==============================] - 0s 410us/step - loss: 0.2337 - accuracy: 0.9366 - val_loss: 0.8115 - val_accuracy: 0.8000
# Epoch 107/200
# 402/402 [==============================] - 0s 439us/step - loss: 0.2301 - accuracy: 0.9291 - val_loss: 0.8018 - val_accuracy: 0.7333
# Epoch 108/200
# 402/402 [==============================] - 0s 428us/step - loss: 0.2241 - accuracy: 0.9353 - val_loss: 0.7836 - val_accuracy: 0.8000
# Epoch 109/200
# 402/402 [==============================] - 0s 420us/step - loss: 0.2320 - accuracy: 0.9316 - val_loss: 0.7868 - val_accuracy: 0.7833
# Epoch 110/200
# 402/402 [==============================] - 0s 408us/step - loss: 0.2359 - accuracy: 0.9279 - val_loss: 0.8021 - val_accuracy: 0.8000
# Epoch 111/200
# 402/402 [==============================] - 0s 409us/step - loss: 0.2211 - accuracy: 0.9328 - val_loss: 0.8385 - val_accuracy: 0.8000
# Epoch 112/200
# 402/402 [==============================] - 0s 415us/step - loss: 0.2299 - accuracy: 0.9229 - val_loss: 0.8194 - val_accuracy: 0.7333
# Epoch 113/200
# 402/402 [==============================] - 0s 415us/step - loss: 0.2230 - accuracy: 0.9378 - val_loss: 0.7949 - val_accuracy: 0.7500
# Epoch 114/200
# 402/402 [==============================] - 0s 419us/step - loss: 0.2257 - accuracy: 0.9291 - val_loss: 0.7606 - val_accuracy: 0.8000
# Epoch 115/200
# 402/402 [==============================] - 0s 422us/step - loss: 0.2178 - accuracy: 0.9341 - val_loss: 0.7986 - val_accuracy: 0.7333
# Epoch 116/200
# 402/402 [==============================] - 0s 417us/step - loss: 0.2261 - accuracy: 0.9366 - val_loss: 0.9380 - val_accuracy: 0.7000
# Epoch 117/200
# 402/402 [==============================] - 0s 378us/step - loss: 0.2378 - accuracy: 0.9216 - val_loss: 0.8410 - val_accuracy: 0.8000
# Epoch 118/200
# 402/402 [==============================] - 0s 382us/step - loss: 0.2177 - accuracy: 0.9303 - val_loss: 0.8417 - val_accuracy: 0.8167
# Epoch 119/200
# 402/402 [==============================] - 0s 384us/step - loss: 0.2183 - accuracy: 0.9353 - val_loss: 0.8578 - val_accuracy: 0.7167
# Epoch 120/200
# 402/402 [==============================] - 0s 394us/step - loss: 0.2110 - accuracy: 0.9303 - val_loss: 0.8382 - val_accuracy: 0.8000
# Epoch 121/200
# 402/402 [==============================] - 0s 389us/step - loss: 0.2100 - accuracy: 0.9328 - val_loss: 0.8473 - val_accuracy: 0.8167
# Epoch 122/200
# 402/402 [==============================] - 0s 390us/step - loss: 0.2075 - accuracy: 0.9403 - val_loss: 0.8453 - val_accuracy: 0.8333
# Epoch 123/200
# 402/402 [==============================] - 0s 402us/step - loss: 0.2109 - accuracy: 0.9378 - val_loss: 0.8113 - val_accuracy: 0.7333
# Epoch 124/200
# 402/402 [==============================] - 0s 396us/step - loss: 0.2293 - accuracy: 0.9378 - val_loss: 0.8231 - val_accuracy: 0.8000
# Epoch 125/200
# 402/402 [==============================] - 0s 398us/step - loss: 0.2121 - accuracy: 0.9291 - val_loss: 0.8311 - val_accuracy: 0.8000
# Epoch 126/200
# 402/402 [==============================] - 0s 403us/step - loss: 0.2138 - accuracy: 0.9328 - val_loss: 0.8341 - val_accuracy: 0.8000
# Epoch 127/200
# 402/402 [==============================] - 0s 426us/step - loss: 0.2259 - accuracy: 0.9303 - val_loss: 0.8563 - val_accuracy: 0.7167
# Epoch 128/200
# 402/402 [==============================] - 0s 425us/step - loss: 0.2142 - accuracy: 0.9366 - val_loss: 0.8343 - val_accuracy: 0.7333
# Epoch 129/200
# 402/402 [==============================] - 0s 420us/step - loss: 0.2210 - accuracy: 0.9328 - val_loss: 0.8741 - val_accuracy: 0.8000
# Epoch 130/200
# 402/402 [==============================] - 0s 419us/step - loss: 0.2225 - accuracy: 0.9378 - val_loss: 0.8704 - val_accuracy: 0.8333
# Epoch 131/200
# 402/402 [==============================] - 0s 398us/step - loss: 0.2179 - accuracy: 0.9403 - val_loss: 0.8680 - val_accuracy: 0.8000
# Epoch 132/200
# 402/402 [==============================] - 0s 401us/step - loss: 0.2159 - accuracy: 0.9378 - val_loss: 0.8588 - val_accuracy: 0.8167
# Epoch 133/200
# 402/402 [==============================] - 0s 421us/step - loss: 0.2144 - accuracy: 0.9391 - val_loss: 0.9008 - val_accuracy: 0.8000
# Epoch 134/200
# 402/402 [==============================] - 0s 421us/step - loss: 0.2060 - accuracy: 0.9366 - val_loss: 0.8712 - val_accuracy: 0.7167
# Epoch 135/200
# 402/402 [==============================] - 0s 420us/step - loss: 0.2273 - accuracy: 0.9291 - val_loss: 0.8658 - val_accuracy: 0.8333
# Epoch 136/200
# 402/402 [==============================] - 0s 409us/step - loss: 0.2070 - accuracy: 0.9391 - val_loss: 0.8404 - val_accuracy: 0.7500
# Epoch 137/200
# 402/402 [==============================] - 0s 408us/step - loss: 0.2154 - accuracy: 0.9353 - val_loss: 0.8435 - val_accuracy: 0.8167
# Epoch 138/200
# 402/402 [==============================] - 0s 414us/step - loss: 0.2215 - accuracy: 0.9378 - val_loss: 0.8675 - val_accuracy: 0.7000
# Epoch 139/200
# 402/402 [==============================] - 0s 407us/step - loss: 0.2180 - accuracy: 0.9316 - val_loss: 0.8339 - val_accuracy: 0.8000
# Epoch 140/200
# 402/402 [==============================] - 0s 395us/step - loss: 0.2192 - accuracy: 0.9391 - val_loss: 0.8557 - val_accuracy: 0.8000
# Epoch 141/200
# 402/402 [==============================] - 0s 386us/step - loss: 0.1975 - accuracy: 0.9403 - val_loss: 0.9098 - val_accuracy: 0.7000
# Epoch 142/200
# 402/402 [==============================] - 0s 381us/step - loss: 0.2234 - accuracy: 0.9316 - val_loss: 0.8551 - val_accuracy: 0.8000
# Epoch 143/200
# 402/402 [==============================] - 0s 411us/step - loss: 0.2071 - accuracy: 0.9353 - val_loss: 0.9105 - val_accuracy: 0.8333
# Epoch 144/200
# 402/402 [==============================] - 0s 416us/step - loss: 0.2176 - accuracy: 0.9366 - val_loss: 0.8984 - val_accuracy: 0.8333
# Epoch 145/200
# 402/402 [==============================] - 0s 402us/step - loss: 0.2060 - accuracy: 0.9341 - val_loss: 0.9202 - val_accuracy: 0.7833
# Epoch 146/200
# 402/402 [==============================] - 0s 396us/step - loss: 0.2094 - accuracy: 0.9403 - val_loss: 0.8956 - val_accuracy: 0.7833
# Epoch 147/200
# 402/402 [==============================] - 0s 375us/step - loss: 0.2027 - accuracy: 0.9403 - val_loss: 0.9501 - val_accuracy: 0.8000
# Epoch 148/200
# 402/402 [==============================] - 0s 385us/step - loss: 0.2039 - accuracy: 0.9403 - val_loss: 0.9283 - val_accuracy: 0.8333
# Epoch 149/200
# 402/402 [==============================] - 0s 418us/step - loss: 0.2069 - accuracy: 0.9391 - val_loss: 0.8977 - val_accuracy: 0.7833
# Epoch 150/200
# 402/402 [==============================] - 0s 415us/step - loss: 0.2053 - accuracy: 0.9316 - val_loss: 1.0678 - val_accuracy: 0.5833
# Epoch 151/200
# 402/402 [==============================] - 0s 415us/step - loss: 0.2479 - accuracy: 0.9167 - val_loss: 0.9519 - val_accuracy: 0.7000
# Epoch 152/200
# 402/402 [==============================] - 0s 411us/step - loss: 0.2110 - accuracy: 0.9378 - val_loss: 0.8933 - val_accuracy: 0.8167
# Epoch 153/200
# 402/402 [==============================] - 0s 384us/step - loss: 0.2012 - accuracy: 0.9440 - val_loss: 1.0285 - val_accuracy: 0.7000
# Epoch 154/200
# 402/402 [==============================] - 0s 411us/step - loss: 0.2178 - accuracy: 0.9378 - val_loss: 0.9085 - val_accuracy: 0.8000
# Epoch 155/200
# 402/402 [==============================] - 0s 370us/step - loss: 0.2215 - accuracy: 0.9403 - val_loss: 0.9267 - val_accuracy: 0.7000
# Epoch 156/200
# 402/402 [==============================] - 0s 379us/step - loss: 0.2008 - accuracy: 0.9366 - val_loss: 0.9044 - val_accuracy: 0.8000
# Epoch 157/200
# 402/402 [==============================] - 0s 382us/step - loss: 0.2059 - accuracy: 0.9378 - val_loss: 0.9112 - val_accuracy: 0.6667
# Epoch 158/200
# 402/402 [==============================] - 0s 386us/step - loss: 0.2096 - accuracy: 0.9328 - val_loss: 0.8842 - val_accuracy: 0.8000
# Epoch 159/200
# 402/402 [==============================] - 0s 392us/step - loss: 0.2023 - accuracy: 0.9378 - val_loss: 0.9162 - val_accuracy: 0.8333
# Epoch 160/200
# 402/402 [==============================] - 0s 395us/step - loss: 0.2051 - accuracy: 0.9403 - val_loss: 0.9285 - val_accuracy: 0.8333
# Epoch 161/200
# 402/402 [==============================] - 0s 404us/step - loss: 0.2083 - accuracy: 0.9428 - val_loss: 0.9269 - val_accuracy: 0.8333
# Epoch 162/200
# 402/402 [==============================] - 0s 394us/step - loss: 0.2012 - accuracy: 0.9415 - val_loss: 0.9437 - val_accuracy: 0.8333
# Epoch 163/200
# 402/402 [==============================] - 0s 377us/step - loss: 0.2101 - accuracy: 0.9328 - val_loss: 0.9344 - val_accuracy: 0.8000
# Epoch 164/200
# 402/402 [==============================] - 0s 428us/step - loss: 0.2154 - accuracy: 0.9353 - val_loss: 0.9028 - val_accuracy: 0.8000
# Epoch 165/200
# 402/402 [==============================] - 0s 396us/step - loss: 0.2117 - accuracy: 0.9415 - val_loss: 0.9270 - val_accuracy: 0.8000
# Epoch 166/200
# 402/402 [==============================] - 0s 414us/step - loss: 0.1919 - accuracy: 0.9403 - val_loss: 0.9390 - val_accuracy: 0.7167
# Epoch 167/200
# 402/402 [==============================] - 0s 410us/step - loss: 0.2113 - accuracy: 0.9341 - val_loss: 0.9706 - val_accuracy: 0.8000
# Epoch 168/200
# 402/402 [==============================] - 0s 413us/step - loss: 0.2004 - accuracy: 0.9403 - val_loss: 1.0606 - val_accuracy: 0.7667
# Epoch 169/200
# 402/402 [==============================] - 0s 411us/step - loss: 0.2118 - accuracy: 0.9353 - val_loss: 1.0350 - val_accuracy: 0.7667
# Epoch 170/200
# 402/402 [==============================] - 0s 406us/step - loss: 0.2054 - accuracy: 0.9341 - val_loss: 0.9628 - val_accuracy: 0.8000
# Epoch 171/200
# 402/402 [==============================] - 0s 414us/step - loss: 0.2103 - accuracy: 0.9341 - val_loss: 0.9271 - val_accuracy: 0.8000
# Epoch 172/200
# 402/402 [==============================] - 0s 407us/step - loss: 0.1987 - accuracy: 0.9378 - val_loss: 0.9942 - val_accuracy: 0.8333
# Epoch 173/200
# 402/402 [==============================] - 0s 403us/step - loss: 0.2031 - accuracy: 0.9403 - val_loss: 0.9647 - val_accuracy: 0.7667
# Epoch 174/200
# 402/402 [==============================] - 0s 405us/step - loss: 0.2063 - accuracy: 0.9353 - val_loss: 0.9997 - val_accuracy: 0.8333
# Epoch 175/200
# 402/402 [==============================] - 0s 417us/step - loss: 0.2034 - accuracy: 0.9391 - val_loss: 0.9142 - val_accuracy: 0.8000
# Epoch 176/200
# 402/402 [==============================] - 0s 409us/step - loss: 0.2020 - accuracy: 0.9391 - val_loss: 0.9377 - val_accuracy: 0.8167
# Epoch 177/200
# 402/402 [==============================] - 0s 406us/step - loss: 0.1976 - accuracy: 0.9366 - val_loss: 0.9828 - val_accuracy: 0.7333
# Epoch 178/200
# 402/402 [==============================] - 0s 411us/step - loss: 0.1922 - accuracy: 0.9440 - val_loss: 1.0209 - val_accuracy: 0.8333
# Epoch 179/200
# 402/402 [==============================] - 0s 406us/step - loss: 0.1890 - accuracy: 0.9378 - val_loss: 1.1179 - val_accuracy: 0.8333
# Epoch 180/200
# 402/402 [==============================] - 0s 390us/step - loss: 0.2051 - accuracy: 0.9353 - val_loss: 1.0030 - val_accuracy: 0.7167
# Epoch 181/200
# 402/402 [==============================] - 0s 427us/step - loss: 0.1975 - accuracy: 0.9378 - val_loss: 0.9598 - val_accuracy: 0.7000
# Epoch 182/200
# 402/402 [==============================] - 0s 415us/step - loss: 0.1992 - accuracy: 0.9403 - val_loss: 0.9678 - val_accuracy: 0.8000
# Epoch 183/200
# 402/402 [==============================] - 0s 407us/step - loss: 0.1923 - accuracy: 0.9391 - val_loss: 1.0063 - val_accuracy: 0.8333
# Epoch 184/200
# 402/402 [==============================] - 0s 418us/step - loss: 0.1922 - accuracy: 0.9403 - val_loss: 0.9980 - val_accuracy: 0.8000
# Epoch 185/200
# 402/402 [==============================] - 0s 401us/step - loss: 0.1918 - accuracy: 0.9378 - val_loss: 1.0134 - val_accuracy: 0.8000
# Epoch 186/200
# 402/402 [==============================] - 0s 389us/step - loss: 0.1988 - accuracy: 0.9353 - val_loss: 1.0127 - val_accuracy: 0.8000
# Epoch 187/200
# 402/402 [==============================] - 0s 410us/step - loss: 0.1981 - accuracy: 0.9428 - val_loss: 0.9820 - val_accuracy: 0.7667
# Epoch 188/200
# 402/402 [==============================] - 0s 482us/step - loss: 0.1930 - accuracy: 0.9403 - val_loss: 1.0115 - val_accuracy: 0.8333
# Epoch 189/200
# 402/402 [==============================] - 0s 495us/step - loss: 0.1921 - accuracy: 0.9391 - val_loss: 1.0602 - val_accuracy: 0.8333
# Epoch 190/200
# 402/402 [==============================] - 0s 482us/step - loss: 0.1985 - accuracy: 0.9353 - val_loss: 0.9874 - val_accuracy: 0.8000
# Epoch 191/200
# 402/402 [==============================] - 0s 519us/step - loss: 0.1962 - accuracy: 0.9366 - val_loss: 1.0499 - val_accuracy: 0.8333
# Epoch 192/200
# 402/402 [==============================] - 0s 442us/step - loss: 0.1994 - accuracy: 0.9328 - val_loss: 0.9936 - val_accuracy: 0.7833
# Epoch 193/200
# 402/402 [==============================] - 0s 417us/step - loss: 0.1867 - accuracy: 0.9415 - val_loss: 1.0427 - val_accuracy: 0.8333
# Epoch 194/200
# 402/402 [==============================] - 0s 407us/step - loss: 0.1874 - accuracy: 0.9391 - val_loss: 1.0207 - val_accuracy: 0.8333
# Epoch 195/200
# 402/402 [==============================] - 0s 438us/step - loss: 0.1929 - accuracy: 0.9378 - val_loss: 0.9820 - val_accuracy: 0.8000
# Epoch 196/200
# 402/402 [==============================] - 0s 458us/step - loss: 0.1976 - accuracy: 0.9378 - val_loss: 0.9762 - val_accuracy: 0.8333
# Epoch 197/200
# 402/402 [==============================] - 0s 458us/step - loss: 0.1895 - accuracy: 0.9353 - val_loss: 1.0428 - val_accuracy: 0.8333
# Epoch 198/200
# 402/402 [==============================] - 0s 470us/step - loss: 0.2054 - accuracy: 0.9391 - val_loss: 1.0961 - val_accuracy: 0.6667
# Epoch 199/200
# 402/402 [==============================] - 0s 553us/step - loss: 0.1966 - accuracy: 0.9328 - val_loss: 1.0052 - val_accuracy: 0.8000
# Epoch 200/200
# 402/402 [==============================] - 0s 447us/step - loss: 0.1860 - accuracy: 0.9378 - val_loss: 1.0659 - val_accuracy: 0.8333

# %%
print("Evaluate on test data")
results = model.evaluate(X_test, y_test, batch_size=128)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 30/30 [==============================] - 0s 122us/step
# test loss, test acc: [1.0659222602844238, 0.8333333134651184]

# %%
history.history
# Out:
# {'val_loss': [0.6479123830795288,
#   0.6310405135154724,
#   0.6348056793212891,
#   0.6256813406944275,
#   0.6091455221176147,
#   0.5980474948883057,
#   0.6215863823890686,
#   0.5920249819755554,
#   0.6039167642593384,
#   0.6138244867324829,
#   0.5888978242874146,
#   0.6217185854911804,
#   0.6051414608955383,
#   0.6001866459846497,
#   0.61141437292099,
#   0.6118262410163879,
#   0.6118953824043274,
#   0.6118243336677551,
#   0.6087400913238525,
#   0.6249372959136963,
#   0.6202828884124756,
#   0.6234808564186096,
#   0.6365843415260315,
#   0.6225503087043762,
#   0.6287418603897095,
#   0.6282329559326172,
#   0.6277069449424744,
#   0.6296083927154541,
#   0.6320516467094421,
#   0.6302323937416077,
#   0.6267893314361572,
#   0.6392428278923035,
#   0.6432687044143677,
#   0.6339836120605469,
#   0.6334362626075745,
#   0.6461011171340942,
#   0.64414381980896,
#   0.643464207649231,
#   0.6422985196113586,
#   0.6647179126739502,
#   0.6550089716911316,
#   0.6483331322669983,
#   0.6516392827033997,
#   0.6468292474746704,
#   0.6512027382850647,
#   0.6509549021720886,
#   0.6617709994316101,
#   0.6569690108299255,
#   0.6540272831916809,
#   0.6682230830192566,
#   0.6605272889137268,
#   0.6571937203407288,
#   0.662591278553009,
#   0.6529053449630737,
#   0.6529154181480408,
#   0.6515743136405945,
#   0.6542466878890991,
#   0.656671404838562,
#   0.6686174869537354,
#   0.6775376200675964,
#   0.66453617811203,
#   0.6746865510940552,
#   0.6649439334869385,
#   0.687006413936615,
#   0.6853824257850647,
#   0.6931386590003967,
#   0.6848199367523193,
#   0.7094948291778564,
#   0.705565869808197,
#   0.7143394351005554,
#   0.7233104705810547,
#   0.7118490934371948,
#   0.7202702164649963,
#   0.7115494012832642,
#   0.7182971835136414,
#   0.7488056421279907,
#   0.7399231791496277,
#   0.7394481301307678,
#   0.7349349856376648,
#   0.7261213064193726,
#   0.735097348690033,
#   0.757228434085846,
#   0.7439343333244324,
#   0.7366387844085693,
#   0.7549694776535034,
#   0.7363526225090027,
#   0.7425113916397095,
#   0.7514601945877075,
#   0.7367590069770813,
#   0.7968998551368713,
#   0.8289684057235718,
#   0.7426100969314575,
#   0.7593950033187866,
#   0.7521461844444275,
#   0.7564211487770081,
#   0.788141131401062,
#   0.790440559387207,
#   0.7770726084709167,
#   0.7474257349967957,
#   0.7449697852134705,
#   0.7680838704109192,
#   0.777647852897644,
#   0.7790683507919312,
#   0.7915595769882202,
#   0.8175770044326782,
#   0.8114712834358215,
#   0.8017674684524536,
#   0.783628523349762,
#   0.786815345287323,
#   0.8021458387374878,
#   0.8385442495346069,
#   0.8193747401237488,
#   0.7948894500732422,
#   0.7605815529823303,
#   0.7986364960670471,
#   0.9380043745040894,
#   0.8409723043441772,
#   0.8416951894760132,
#   0.8578022718429565,
#   0.8382478356361389,
#   0.8472957015037537,
#   0.8453224897384644,
#   0.8112935423851013,
#   0.8230517506599426,
#   0.8311066031455994,
#   0.8340798020362854,
#   0.8563359379768372,
#   0.8342503309249878,
#   0.8741052746772766,
#   0.8703691959381104,
#   0.8680323362350464,
#   0.8588419556617737,
#   0.9008132815361023,
#   0.8712406158447266,
#   0.8658053874969482,
#   0.8403605222702026,
#   0.8435125946998596,
#   0.8674891591072083,
#   0.8338759541511536,
#   0.855692982673645,
#   0.9097761511802673,
#   0.8551446199417114,
#   0.9104824662208557,
#   0.898370623588562,
#   0.9201716184616089,
#   0.8956098556518555,
#   0.9501045346260071,
#   0.9283469915390015,
#   0.8976709842681885,
#   1.0678426027297974,
#   0.951895534992218,
#   0.8933382034301758,
#   1.028528094291687,
#   0.9084936380386353,
#   0.9266518354415894,
#   0.9043516516685486,
#   0.9111579656600952,
#   0.884188711643219,
#   0.9162040948867798,
#   0.9284698367118835,
#   0.9268600344657898,
#   0.9437317252159119,
#   0.9343936443328857,
#   0.9027610421180725,
#   0.9270192980766296,
#   0.938957929611206,
#   0.9705625772476196,
#   1.060638189315796,
#   1.035014271736145,
#   0.9627564549446106,
#   0.9271209836006165,
#   0.9942054748535156,
#   0.9646521210670471,
#   0.9996949434280396,
#   0.9141561388969421,
#   0.9376938939094543,
#   0.9828259348869324,
#   1.020937442779541,
#   1.1178879737854004,
#   1.0030149221420288,
#   0.9597612023353577,
#   0.9677810668945312,
#   1.0063127279281616,
#   0.9980129599571228,
#   1.0133695602416992,
#   1.0126771926879883,
#   0.981986403465271,
#   1.01145601272583,
#   1.0601564645767212,
#   0.9873596429824829,
#   1.049917221069336,
#   0.9935874342918396,
#   1.0427491664886475,
#   1.020714521408081,
#   0.9820290207862854,
#   0.9762293696403503,
#   1.0427756309509277,
#   1.0961143970489502,
#   1.0052310228347778,
#   1.0659222602844238],
#  'val_accuracy': [0.7666666507720947,
#   0.7666666507720947,
#   0.699999988079071,
#   0.699999988079071,
#   0.6833333373069763,
#   0.75,
#   0.6000000238418579,
#   0.6499999761581421,
#   0.6166666746139526,
#   0.6166666746139526,
#   0.6166666746139526,
#   0.6166666746139526,
#   0.6166666746139526,
#   0.6166666746139526,
#   0.6000000238418579,
#   0.6166666746139526,
#   0.6166666746139526,
#   0.6333333253860474,
#   0.6333333253860474,
#   0.6000000238418579,
#   0.6000000238418579,
#   0.5666666626930237,
#   0.6333333253860474,
#   0.5833333134651184,
#   0.6000000238418579,
#   0.5666666626930237,
#   0.6166666746139526,
#   0.6000000238418579,
#   0.6000000238418579,
#   0.6333333253860474,
#   0.6166666746139526,
#   0.6333333253860474,
#   0.6333333253860474,
#   0.6000000238418579,
#   0.6333333253860474,
#   0.6666666865348816,
#   0.6666666865348816,
#   0.6000000238418579,
#   0.5833333134651184,
#   0.6333333253860474,
#   0.6666666865348816,
#   0.6499999761581421,
#   0.6000000238418579,
#   0.5833333134651184,
#   0.6166666746139526,
#   0.6333333253860474,
#   0.6666666865348816,
#   0.699999988079071,
#   0.6666666865348816,
#   0.6166666746139526,
#   0.6000000238418579,
#   0.6166666746139526,
#   0.6333333253860474,
#   0.699999988079071,
#   0.699999988079071,
#   0.699999988079071,
#   0.699999988079071,
#   0.699999988079071,
#   0.699999988079071,
#   0.6333333253860474,
#   0.699999988079071,
#   0.699999988079071,
#   0.6833333373069763,
#   0.6833333373069763,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.6833333373069763,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.6833333373069763,
#   0.699999988079071,
#   0.7166666388511658,
#   0.75,
#   0.7333333492279053,
#   0.7333333492279053,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.75,
#   0.75,
#   0.7333333492279053,
#   0.75,
#   0.75,
#   0.75,
#   0.7333333492279053,
#   0.7333333492279053,
#   0.7333333492279053,
#   0.7333333492279053,
#   0.75,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.75,
#   0.7666666507720947,
#   0.75,
#   0.7333333492279053,
#   0.7333333492279053,
#   0.7333333492279053,
#   0.7166666388511658,
#   0.7333333492279053,
#   0.7333333492279053,
#   0.800000011920929,
#   0.800000011920929,
#   0.7666666507720947,
#   0.800000011920929,
#   0.800000011920929,
#   0.800000011920929,
#   0.7333333492279053,
#   0.800000011920929,
#   0.7833333611488342,
#   0.800000011920929,
#   0.800000011920929,
#   0.7333333492279053,
#   0.75,
#   0.800000011920929,
#   0.7333333492279053,
#   0.699999988079071,
#   0.800000011920929,
#   0.8166666626930237,
#   0.7166666388511658,
#   0.800000011920929,
#   0.8166666626930237,
#   0.8333333134651184,
#   0.7333333492279053,
#   0.800000011920929,
#   0.800000011920929,
#   0.800000011920929,
#   0.7166666388511658,
#   0.7333333492279053,
#   0.800000011920929,
#   0.8333333134651184,
#   0.800000011920929,
#   0.8166666626930237,
#   0.800000011920929,
#   0.7166666388511658,
#   0.8333333134651184,
#   0.75,
#   0.8166666626930237,
#   0.699999988079071,
#   0.800000011920929,
#   0.800000011920929,
#   0.699999988079071,
#   0.800000011920929,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.7833333611488342,
#   0.7833333611488342,
#   0.800000011920929,
#   0.8333333134651184,
#   0.7833333611488342,
#   0.5833333134651184,
#   0.699999988079071,
#   0.8166666626930237,
#   0.699999988079071,
#   0.800000011920929,
#   0.699999988079071,
#   0.800000011920929,
#   0.6666666865348816,
#   0.800000011920929,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.800000011920929,
#   0.800000011920929,
#   0.800000011920929,
#   0.7166666388511658,
#   0.800000011920929,
#   0.7666666507720947,
#   0.7666666507720947,
#   0.800000011920929,
#   0.800000011920929,
#   0.8333333134651184,
#   0.7666666507720947,
#   0.8333333134651184,
#   0.800000011920929,
#   0.8166666626930237,
#   0.7333333492279053,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.7166666388511658,
#   0.699999988079071,
#   0.800000011920929,
#   0.8333333134651184,
#   0.800000011920929,
#   0.800000011920929,
#   0.800000011920929,
#   0.7666666507720947,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.800000011920929,
#   0.8333333134651184,
#   0.7833333611488342,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.800000011920929,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.6666666865348816,
#   0.800000011920929,
#   0.8333333134651184],
#  'loss': [0.689247504988713,
#   0.6573044026075904,
#   0.6400574312281253,
#   0.6340429035585318,
#   0.6165580536002544,
#   0.6027971603977147,
#   0.5958076857808811,
#   0.5857981768117022,
#   0.5768626007571149,
#   0.576509032676469,
#   0.55884226533904,
#   0.5572008552835949,
#   0.546122853880498,
#   0.5384813253559283,
#   0.5347987222137736,
#   0.5349584791197706,
#   0.5312642259384269,
#   0.521939823876566,
#   0.525031199650978,
#   0.5163619220256805,
#   0.5136080410943102,
#   0.5061907946173825,
#   0.4998258743713151,
#   0.4993137810657273,
#   0.4922729316932052,
#   0.4919029745593,
#   0.4846239098862036,
#   0.47864293740756475,
#   0.4708052700135245,
#   0.4784472415696329,
#   0.4768009790733679,
#   0.470835741776139,
#   0.46244822642696437,
#   0.463763226324053,
#   0.4514085588170521,
#   0.45522809918247054,
#   0.44980001316141727,
#   0.44961200142974284,
#   0.4425526932993932,
#   0.44067475333142636,
#   0.4355203091208614,
#   0.4351579275593829,
#   0.423748352634373,
#   0.4211061819275813,
#   0.41844465127631797,
#   0.4246503603992178,
#   0.4258211477478938,
#   0.4138757074946788,
#   0.4129492467019095,
#   0.40768754393307133,
#   0.3925618391428421,
#   0.393804404272962,
#   0.3873609179881082,
#   0.3869673176043069,
#   0.37854414844690865,
#   0.37993458158044674,
#   0.3713738584696357,
#   0.38118552627848157,
#   0.3913327998189784,
#   0.3780595780308567,
#   0.38504683615556407,
#   0.3718434643389574,
#   0.36245374893074606,
#   0.3572277738087213,
#   0.35326566869643194,
#   0.33430382008872817,
#   0.3247794535622668,
#   0.3273133544334725,
#   0.3136190391743361,
#   0.3139882094379681,
#   0.32807333300362773,
#   0.3124004157621469,
#   0.3027947629565623,
#   0.3088156149458529,
#   0.2978091964970774,
#   0.28444406078822576,
#   0.2780720293521881,
#   0.28736206488822824,
#   0.2744184607890115,
#   0.2742202822397004,
#   0.26912395255779153,
#   0.28145010591442904,
#   0.2771143519611501,
#   0.25090236183422715,
#   0.26157172980593213,
#   0.2572540712000719,
#   0.25286982530978186,
#   0.24399266269669603,
#   0.25431175040664955,
#   0.2616786918978193,
#   0.2570414235120389,
#   0.2822850309868357,
#   0.2798624690344085,
#   0.24485145131153846,
#   0.23597147560386517,
#   0.2577730739739404,
#   0.2437403224297424,
#   0.24603237500831263,
#   0.2417613354636662,
#   0.23469664712450397,
#   0.23985816427131199,
#   0.24205639124361436,
#   0.233935584995284,
#   0.23365921927476996,
#   0.23285102710795047,
#   0.23372038865267342,
#   0.23013460013403822,
#   0.22414253362968786,
#   0.23203595127187557,
#   0.23594735496079744,
#   0.22110357413541026,
#   0.22986601315327546,
#   0.2229699832734777,
#   0.22572009965999804,
#   0.21778091977336514,
#   0.22609741629949257,
#   0.2377870073959009,
#   0.21770271792340634,
#   0.2182513224099999,
#   0.21100198510867446,
#   0.2100186392442504,
#   0.20753846473213453,
#   0.21091165615996318,
#   0.2293421095654146,
#   0.21209870501240688,
#   0.21376828248821086,
#   0.22590552715223228,
#   0.21419385687183978,
#   0.2209514542969305,
#   0.2225281641776882,
#   0.2179363328796714,
#   0.21590967832216576,
#   0.21437174626695576,
#   0.2060368719385631,
#   0.22726040878402654,
#   0.20700311549563907,
#   0.21544829411293143,
#   0.22152259245292463,
#   0.21801606510112534,
#   0.21924590008027517,
#   0.19749783824628858,
#   0.2234307785532368,
#   0.20709764801744204,
#   0.21764869376349805,
#   0.2060215440926267,
#   0.20938003107682981,
#   0.20272746848971096,
#   0.20386462525200488,
#   0.20692482034661877,
#   0.20530106316306698,
#   0.24785494248368847,
#   0.2109578475356102,
#   0.201164662170766,
#   0.21782285264178888,
#   0.22148810638420618,
#   0.20082191500201155,
#   0.20591019427598412,
#   0.2096279604888674,
#   0.20226001756182357,
#   0.20513387046643158,
#   0.20829983033351043,
#   0.20119578647079753,
#   0.21005289156490298,
#   0.21535276110047724,
#   0.21168180688548444,
#   0.1919002883247475,
#   0.21133679318339077,
#   0.20036048064036155,
#   0.2117682666476093,
#   0.2053789304041151,
#   0.21033689679939355,
#   0.19873547175926948,
#   0.20312139269576143,
#   0.20630349785979116,
#   0.20344875886369107,
#   0.20202937655484499,
#   0.19757813348698972,
#   0.1922203372441121,
#   0.18895040686005976,
#   0.20506834722499348,
#   0.19751269970812016,
#   0.1992498502802493,
#   0.19225705781979346,
#   0.19216796700189362,
#   0.19176150535914435,
#   0.19884675574391636,
#   0.1981087232481188,
#   0.19295277780116493,
#   0.19207569645411932,
#   0.19848995266565636,
#   0.19622544321551252,
#   0.19935357303761725,
#   0.18665403961690505,
#   0.18737298917414538,
#   0.19288338642956607,
#   0.1975977655444572,
#   0.18948398141273812,
#   0.2053545406505243,
#   0.19664311542439816,
#   0.18602587460581935],
#  'accuracy': [0.5136816,
#   0.5708955,
#   0.5995025,
#   0.6318408,
#   0.670398,
#   0.7300995,
#   0.6902985,
#   0.74129355,
#   0.76741296,
#   0.75248754,
#   0.80472636,
#   0.76741296,
#   0.8097015,
#   0.8233831,
#   0.8022388,
#   0.8208955,
#   0.8159204,
#   0.8221393,
#   0.81467664,
#   0.8208955,
#   0.82462686,
#   0.83830845,
#   0.8271144,
#   0.8271144,
#   0.82587063,
#   0.8308458,
#   0.83457714,
#   0.8333333,
#   0.8470149,
#   0.8432836,
#   0.84577113,
#   0.8470149,
#   0.8507463,
#   0.8507463,
#   0.8532338,
#   0.8544776,
#   0.8606965,
#   0.8606965,
#   0.869403,
#   0.85820895,
#   0.8557214,
#   0.8631841,
#   0.8706468,
#   0.86442786,
#   0.8768657,
#   0.8594527,
#   0.8606965,
#   0.869403,
#   0.86442786,
#   0.87810946,
#   0.8793532,
#   0.8731343,
#   0.8768657,
#   0.87810946,
#   0.880597,
#   0.8818408,
#   0.8905473,
#   0.88432837,
#   0.8818408,
#   0.8868159,
#   0.8681592,
#   0.89179105,
#   0.89800996,
#   0.8830846,
#   0.8893035,
#   0.8992537,
#   0.90422887,
#   0.90174127,
#   0.909204,
#   0.9029851,
#   0.8893035,
#   0.90174127,
#   0.91169155,
#   0.9029851,
#   0.9067164,
#   0.91169155,
#   0.9129353,
#   0.9129353,
#   0.9228856,
#   0.91542286,
#   0.9141791,
#   0.9079602,
#   0.91169155,
#   0.9191542,
#   0.9141791,
#   0.91542286,
#   0.9141791,
#   0.9166667,
#   0.9266169,
#   0.9129353,
#   0.9166667,
#   0.9079602,
#   0.9104478,
#   0.9291045,
#   0.92412937,
#   0.9191542,
#   0.9291045,
#   0.92537314,
#   0.9340796,
#   0.92164177,
#   0.93159205,
#   0.93159205,
#   0.9303483,
#   0.93159205,
#   0.9278607,
#   0.9365672,
#   0.9291045,
#   0.93532336,
#   0.93159205,
#   0.9278607,
#   0.9328358,
#   0.9228856,
#   0.93781096,
#   0.9291045,
#   0.9340796,
#   0.9365672,
#   0.92164177,
#   0.9303483,
#   0.93532336,
#   0.9303483,
#   0.9328358,
#   0.9402985,
#   0.93781096,
#   0.93781096,
#   0.9291045,
#   0.9328358,
#   0.9303483,
#   0.9365672,
#   0.9328358,
#   0.93781096,
#   0.9402985,
#   0.93781096,
#   0.9390547,
#   0.9365672,
#   0.9291045,
#   0.9390547,
#   0.93532336,
#   0.93781096,
#   0.93159205,
#   0.9390547,
#   0.9402985,
#   0.93159205,
#   0.93532336,
#   0.9365672,
#   0.9340796,
#   0.9402985,
#   0.9402985,
#   0.9402985,
#   0.9390547,
#   0.93159205,
#   0.9166667,
#   0.93781096,
#   0.94402987,
#   0.93781096,
#   0.9402985,
#   0.9365672,
#   0.93781096,
#   0.9328358,
#   0.93781096,
#   0.9402985,
#   0.9427861,
#   0.94154227,
#   0.9328358,
#   0.93532336,
#   0.94154227,
#   0.9402985,
#   0.9340796,
#   0.9402985,
#   0.93532336,
#   0.9340796,
#   0.9340796,
#   0.93781096,
#   0.9402985,
#   0.93532336,
#   0.9390547,
#   0.9390547,
#   0.9365672,
#   0.94402987,
#   0.93781096,
#   0.93532336,
#   0.93781096,
#   0.9402985,
#   0.9390547,
#   0.9402985,
#   0.93781096,
#   0.93532336,
#   0.9427861,
#   0.9402985,
#   0.9390547,
#   0.93532336,
#   0.9365672,
#   0.9328358,
#   0.94154227,
#   0.9390547,
#   0.93781096,
#   0.93781096,
#   0.93532336,
#   0.9390547,
#   0.9328358,
#   0.93781096]}
